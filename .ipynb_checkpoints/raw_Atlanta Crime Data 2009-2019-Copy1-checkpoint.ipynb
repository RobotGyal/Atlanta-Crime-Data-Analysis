# %% [markdown]
# # ***Atlanta Crime Data 2009-2019***
# ---
# ---

# %% [markdown]
# ## Research / Resources
# ---

# %% [markdown]
# __Definitions__
# - '**Beat**' - "The City of Atlanta is divided into six unique geographic areas – known as Zones – for the purposes of allocating APD resources. Each Zone is then divided into 13-14 “beats” assigned to a specific officer for patrol purposes.".
#
# - '**UCR**' - Uniform Crime Reporting Number. This number classifies a crime using a number system. Links to chart attached.
#
# - '**IBR**' - Allows for more specific crime types.
#
# - '**NPU**' - "The City of Atlanta is divided into twenty-five (25) Neighborhood Planning Units (NPUs), which are citizen advisory councils that make recommendations to the Mayor and City Council on zoning, land use, and other planning-related matters. ".
#
#
# __Research__
# [Atlanta Police Beat and Zones](https://www.atlantapd.org/Home/Components/News/News/190/)
# [NIBRS](https://www.atlantapd.org/Home/ShowDocument?id=2881)
# [UCR CLASSIFICATION ABBREVIATIONS](https://www.atlantapd.org/Home/ShowDocument?id=2200)
# [Atlanta Police Department Crime Data Downloads](https://www.atlantapd.org/i-want-to/crime-data-downloads)
# [Uniform Crime Reporting Handbook](https://ucr.fbi.gov/additional-ucr-publications/ucr_handbook.pdf)

# %% [markdown]
# ## Zones / NPU
# ---
#
# <img src="zones.png">

# %% [markdown]
# ## Imports
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats
import plotly.express as px
from datetime import datetime
from geopy.geocoders import Nominatim
import geopy as gp

# %% [markdown]
# ## Data
# ---

# %%
atlanta = pd.read_csv("COBRA-2009-2019 (Updated 1_9_2020)/COBRA-2009-2019.csv")

atlanta.head()
# Out:
# /Users/aleia/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning:
#
# Columns (3,11) have mixed types.Specify dtype option on import or set low_memory=False.
#    Report Number Report Date  Occur Date Occur Time Possible Date  \
# 0       90010930  2009-01-01  2009-01-01       1145    2009-01-01
# 1       90011083  2009-01-01  2009-01-01       1330    2009-01-01
# 2       90011208  2009-01-01  2009-01-01       1500    2009-01-01
# 3       90011218  2009-01-01  2009-01-01       1450    2009-01-01
# 4       90011289  2009-01-01  2009-01-01       1600    2009-01-01
#
#    Possible Time   Beat Apartment Office Prefix Apartment Number  \
# 0         1148.0  411.0                     NaN              NaN
# 1         1330.0  511.0                     NaN              NaN
# 2         1520.0  407.0                     NaN              NaN
# 3         1510.0  210.0                     NaN              NaN
# 4         1700.0  411.0                     NaN              NaN
#
#                       Location Shift Occurence Location Type  \
# 0         2841 GREENBRIAR PKWY       Day Watch             8
# 1               12 BROAD ST SW       Day Watch             9
# 2  3500 MARTIN L KING JR DR SW         Unknown             8
# 3         3393 PEACHTREE RD NE   Evening Watch             8
# 4      2841 GREENBRIAR PKWY SW         Unknown             8
#
#            UCR Literal  UCR # IBR Code Neighborhood NPU  Latitude  Longitude
# 0  LARCENY-NON VEHICLE    630     2303   Greenbriar   R  33.68845  -84.49328
# 1  LARCENY-NON VEHICLE    630     2303     Downtown   M  33.75320  -84.39201
# 2  LARCENY-NON VEHICLE    630     2303   Adamsville   H  33.75735  -84.50282
# 3  LARCENY-NON VEHICLE    630     2303        Lenox   B  33.84676  -84.36212
# 4  LARCENY-NON VEHICLE    630     2303   Greenbriar   R  33.68677  -84.49773

# %% [markdown]
# ## Quick Look
# ---

# %%
print(atlanta.describe(), '\n\n\n')

atlanta.info()
# Out:
#        Report Number  Possible Time           Beat          UCR #  \
# count   3.429140e+05  342895.000000  342890.000000  342914.000000
# mean    1.375665e+08    1310.068065     365.391277     594.856463
# std     3.146330e+07     643.618899     170.580194     111.848817
# min     6.104028e+07       0.000000       0.000000     110.000000
# 25%     1.112706e+08     830.000000     209.000000     511.000000
# 50%     1.331526e+08    1350.000000     402.000000     640.000000
# 75%     1.625932e+08    1830.000000     507.000000     670.000000
# max     2.000724e+08    3015.000000     614.000000     730.000000
#
#             Latitude      Longitude
# count  342914.000000  342914.000000
# mean       33.757281     -84.407407
# std         0.044930       0.047112
# min        33.637500     -84.550500
# 25%        33.730310     -84.432130
# 50%        33.756670     -84.396360
# 75%        33.781830     -84.373470
# max        33.886130     -84.286410
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342914 entries, 0 to 342913
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Report Number            342914 non-null  int64
#  1   Report Date              342914 non-null  object
#  2   Occur Date               342914 non-null  object
#  3   Occur Time               342914 non-null  object
#  4   Possible Date            342896 non-null  object
#  5   Possible Time            342895 non-null  float64
#  6   Beat                     342890 non-null  float64
#  7   Apartment Office Prefix  10094 non-null   object
#  8   Apartment Number         68274 non-null   object
#  9   Location                 342912 non-null  object
#  10  Shift Occurence          342914 non-null  object
#  11  Location Type            333698 non-null  object
#  12  UCR Literal              342914 non-null  object
#  13  UCR #                    342914 non-null  int64
#  14  IBR Code                 342744 non-null  object
#  15  Neighborhood             330551 non-null  object
#  16  NPU                      342775 non-null  object
#  17  Latitude                 342914 non-null  float64
#  18  Longitude                342914 non-null  float64
# dtypes: float64(4), int64(2), object(13)
# memory usage: 49.7+ MB

# %% [markdown]
# ## Cleaning
# ---

# %%
#Columns to drop based on necessity
dropped_columns = ['Apartment Office Prefix', 'Apartment Number', 'Location', 'Location Type', 'Report Number']
atlanta = atlanta.drop(dropped_columns, axis=1)

# For converting code to crime group
def codes_to_crimes(value):
    if value > 100 and value < 199:
        return 'Homicide'
    elif value > 200 and value < 299:
        return 'Rape'
    elif value > 300 and value < 399:
        return 'Robbery'
    elif value > 400 and value < 499:
        return 'Assault'
    elif value > 500 and value < 599:
        return 'Burglary'
    elif value > 600 and value < 699:
        return 'Larceny'
    elif value > 700 and value < 799:
        return 'Motor_theft'
    elif value > 800 and value < 899:
        return 'Arson'
atlanta['Crime'] = pd.Series(atlanta['UCR #']).apply(codes_to_crimes).astype('str')


atlanta.head()
# Out:
#   Report Date  Occur Date Occur Time Possible Date  Possible Time   Beat  \
# 0  2009-01-01  2009-01-01       1145    2009-01-01         1148.0  411.0
# 1  2009-01-01  2009-01-01       1330    2009-01-01         1330.0  511.0
# 2  2009-01-01  2009-01-01       1500    2009-01-01         1520.0  407.0
# 3  2009-01-01  2009-01-01       1450    2009-01-01         1510.0  210.0
# 4  2009-01-01  2009-01-01       1600    2009-01-01         1700.0  411.0
#
#   Shift Occurence          UCR Literal  UCR # IBR Code Neighborhood NPU  \
# 0       Day Watch  LARCENY-NON VEHICLE    630     2303   Greenbriar   R
# 1       Day Watch  LARCENY-NON VEHICLE    630     2303     Downtown   M
# 2         Unknown  LARCENY-NON VEHICLE    630     2303   Adamsville   H
# 3   Evening Watch  LARCENY-NON VEHICLE    630     2303        Lenox   B
# 4         Unknown  LARCENY-NON VEHICLE    630     2303   Greenbriar   R
#
#    Latitude  Longitude    Crime
# 0  33.68845  -84.49328  Larceny
# 1  33.75320  -84.39201  Larceny
# 2  33.75735  -84.50282  Larceny
# 3  33.84676  -84.36212  Larceny
# 4  33.68677  -84.49773  Larceny

# %% [markdown]
# ## Sampling
# ---

# %%
# *****************************
# HIGHLY IMPORTANT while testing
# *****************************

# Sample data
print("Original Data Stats: \n")
print(atlanta.describe())

print('\n--------\n')

atlanta = atlanta.sample(frac=0.01)  # 1% sample set
print(atlanta.describe())
# Out:
# Original Data Stats:
#
#        Possible Time           Beat          UCR #       Latitude  \
# count  342895.000000  342890.000000  342914.000000  342914.000000
# mean     1310.068065     365.391277     594.856463      33.757281
# std       643.618899     170.580194     111.848817       0.044930
# min         0.000000       0.000000     110.000000      33.637500
# 25%       830.000000     209.000000     511.000000      33.730310
# 50%      1350.000000     402.000000     640.000000      33.756670
# 75%      1830.000000     507.000000     670.000000      33.781830
# max      3015.000000     614.000000     730.000000      33.886130
#
#            Longitude
# count  342914.000000
# mean      -84.407407
# std         0.047112
# min       -84.550500
# 25%       -84.432130
# 50%       -84.396360
# 75%       -84.373470
# max       -84.286410
#
# --------
#
#        Possible Time         Beat        UCR #     Latitude    Longitude
# count    3428.000000  3429.000000  3429.000000  3429.000000  3429.000000
# mean     1303.984539   365.093322   595.334791    33.757759   -84.406963
# std       643.207768   172.217511   109.582710     0.043810     0.046632
# min         0.000000     0.000000   110.000000    33.648830   -84.548510
# 25%       830.000000   208.000000   512.000000    33.733340   -84.430960
# 50%      1345.000000   402.000000   640.000000    33.756620   -84.396140
# 75%      1820.000000   508.000000   670.000000    33.781780   -84.374090
# max      2359.000000   614.000000   730.000000    33.879570   -84.290740

# %% [markdown]
# ## Heatmap Correlation
# ---

# %%
sns.heatmap(atlanta.corr())

# %% [markdown]
# _Conclusions_
#
# ---
# Most can be ignored, but the 'Beat' vs 'UCR #' is interesting. It is not a high correlation but one is there. It does show that there is at least some relation between the Zone of town lived in and the type of crime committed.

# %% [markdown]
# ## Pairplot
# ---

# %%
# sns.pairplot(atlanta)
# plt.show()

# %% [markdown]
# _Conclusions_
#
# ---
# .....

# %% [markdown]
# ## Pie chart of Crimes
# ---

# %%
fig = px.pie(atlanta, values='UCR #', names='Crime', title='Crimes in Atlanta', color_discrete_sequence=px.colors.sequential.RdBu)
fig.show()
# Out:
# <div>
#
#
#             <div id="e7297c75-0dd0-4a45-bc87-95faf2479545" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e7297c75-0dd0-4a45-bc87-95faf2479545")) {
#                     Plotly.newPlot(
#                         'e7297c75-0dd0-4a45-bc87-95faf2479545',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Crime=%{label}<br>UCR #=%{value}<extra></extra>", "labels": ["Larceny", "Robbery", "Larceny", "Larceny", "Motor_theft", "Motor_theft", "Larceny", "Motor_theft", "Larceny", "Burglary", "Robbery", "Robbery", "Motor_theft", "Larceny", "Larceny", "Assault", "Larceny", "Robbery", "Motor_theft", "Larceny", "Burglary", "Burglary", "Larceny", "Larceny", "Larceny", "Burglary", "Larceny", "Larceny", "Larceny", "Burglary", "Larceny", "Burglary", "Larceny", "Homicide", "Larceny", "Larceny", "Larceny", "Larceny", "Larceny", "Burglary", "Burglary", "Larceny", "Larceny", "Larceny", "Burglary", "Burglary", "Larceny", "Larceny", "Larceny", "Larceny", "Robbery", "Motor_theft", "Assault", "Burglary", "Motor_theft", "Larceny", "Larceny", "Larceny", "Larceny", "Motor_theft", "Larceny", "Burglary", "Larceny", "Larceny", "Burglary", "Larceny", "Motor_theft", "Larceny", "Larceny", "Larceny", "Burglary", "Larceny", "Motor_theft", "Burglary", "Larceny", "Motor_theft", "Burglary", "Larceny", "Larceny", "Larceny", "Burglary", "Larceny", "Larceny", "Motor_theft", "Larceny", "Larceny", "Larceny", "Motor_theft", "Assault", "Larceny", "Assault", "Larceny", "Motor_theft", "Larceny", "Burglary", "Burglary", "Larceny", "Motor_theft", "Motor_theft", "Larceny", "Assault", "Larceny", "Motor_theft", "Robbery", "Larceny", "Robbery", "Robbery", "Larceny", "Larceny", "Burglary", "Larceny", "Burglary", "Motor_theft", "Larceny", "Larceny", "Assault", "Assault", "Larceny", "Larceny", "Larceny", "Burglary", "Assault", "Burglary", "Burglary", "Larceny", "Larceny", "Motor_theft", "Burglary", "Larceny", "Larceny", "Assault", "Larceny", "Burglary", "Larceny", "Larceny", "Larceny", "Motor_theft", "Larceny", "Motor_theft", "Larceny", "Motor_theft", "Larceny", "Larceny", "Larceny", "Larceny", "Larceny", "Larceny", "Motor_theft", "Motor_theft", "Motor_theft", "Larceny", "Larceny", "Larceny", "Larceny", "Assault", "Motor_theft", "Motor_theft", "Larceny", "Robbery", "Larceny", "Burglary", "Larceny", "Larceny", "Motor_theft", "Robbery", "Larceny", "Robbery", "Burglary", "Larceny", "Larceny", "Robbery", "Burglary", "Larceny", "Burglary", "Larceny", "Larceny", "Larceny", "Larceny", "Assault", "Larceny", "Burglary", "Larceny", "Assault", "Burglary", "Burglary", "Assault", "Larceny", "Burglary", "Burglary", "Motor_theft", "Larceny", "Motor_theft", "Larceny", "Motor_theft", "Motor_theft", "Larceny", "Larceny", "Larceny", "Burglary", "Burglary", "Larceny", "Larceny", "Larceny", "Motor_theft", "Larceny", "Robbery", "Assault", "Burglary", "Burglary", "Larceny", "Larceny", "Larceny", "Larceny", "Larceny", "Robbery", "Larceny", "Larceny", "Robbery", "Burglary", "Assault", "Larceny", "Burglary", "Burglary", "Assault", "Larceny", "Burglary", "Burglary", "Larceny", "Larceny", "Larceny", "Larceny", "Larceny", "Larceny", "Larceny", "Larceny", "Assault", "Motor_theft", "Larceny", "Larceny", "Burglary", "Motor_theft", "Larceny", "Burglary", "Larceny", "Larceny", "Larceny", "Motor_theft", "Burglary", "Larceny", "Burglary", "Larceny", "Larceny", "Larceny", "Larceny", "Burglary", "Burglary", "Larceny", "Motor_theft", "Larceny", "Burglary", "Larceny", "Motor_theft", "Burglary", "Burglary", "Larceny", "Burglary", "Larceny", "Larceny", "Motor_theft", "Motor_theft", "Burglary", "Larceny", "Burglary", "Larceny", "Burglary", "Larceny", "Motor_theft", "Assault", "Robbery", "Larceny", "Larceny", "Motor_theft", "Larceny", "Larceny", "Assault", "Burglary", "Larceny", "Robbery", "Motor_theft", "Larceny", "Burglary", "Larceny", "Motor_theft", "Robbery", "Larceny", "Larceny", "Assault", "Larceny", "Assault", "Burglary", "Motor_theft", "Larceny", "Larceny", "Robbery", "Assault", "Burglary", "Larceny", "Larceny", "Larceny", "Larceny", "Burglary", "Motor_theft", "Assault", "Larceny", "Robbery", "Larceny", "Larceny", "Larceny", "Larceny", "Larceny", "Larceny", "Motor_theft", "Larceny", "Larceny", "Robbery", "Larceny", "Assault", " ...

# %% [markdown]
# _Conclusions_
#
# ---
# No arsons or rapes were reported! Not sure if this is due to gaps in the data reporting...

# %% [markdown]
# ## Crime Levels per Neighborhood
# ---

# %%
fig = px.histogram(atlanta, x="Neighborhood", title='Crime by Neighborhood')
fig.show()
# Out:
# <div>
#
#
#             <div id="c7a1a3aa-06c0-4736-bc31-a9a4d09e70b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c7a1a3aa-06c0-4736-bc31-a9a4d09e70b9")) {
#                     Plotly.newPlot(
#                         'c7a1a3aa-06c0-4736-bc31-a9a4d09e70b9',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Neighborhood=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["Edgewood", "Florida Heights", "Oakland City", "Midtown", "Sylvan Hills", "Buckhead Forest", "Garden Hills", "Midtown", "Pittsburgh", "Oakland City", "Venetian Hills", "Mechanicsville", "Carey Park", "Greenbriar", "Harland Terrace", "Mays", "Underwood Hills", "Atlanta University Center", "English Avenue", null, "West End", "Thomasville Heights", null, "Grant Park", "West End", "Campbellton Road", "South Tuxedo Park", "Midtown", "Wesley Battle", "Downtown", "Downtown", "Wesley Battle", "West End", "Campbellton Road", "Midtown", "West End", "Downtown", "Downtown", "West Paces Ferry/Northside", "Peachtree Hills", "The Villages at East Lake", "Midtown", "Atlanta Industrial Park", "Piedmont Heights", "South River Gardens", "Knight Park/Howell Station", "Venetian Hills", "Vine City", "Paces", "Pine Hills", "Harland Terrace", "Summerhill", "Mechanicsville", "Lindridge/Martin Manor", "Center Hill", "Lenox", "Adamsville", "Sweet Auburn", "Berkeley Park", "Cascade Avenue/Road", "Downtown", "Peoplestown", "Midtown", "Brandon", "Adair Park", "Florida Heights", "Home Park", null, "Monroe Heights", "Downtown", "Berkeley Park", "Westview", "Pittsburgh", "Capitol View", "Cascade Avenue/Road", "Mays", "Lindbergh/Morosgo", "Midtown", "Midtown", "Downtown", "East Atlanta", "The Villages at Carver", "Piedmont Heights", "Adair Park", "Midtown", "Old Fourth Ward", "Brookview Heights", "Ashview Heights", "Midtown", "West End", "Thomasville Heights", "Adamsville", "Sweet Auburn", "Lindbergh/Morosgo", "North Buckhead", "Lakewood", "Downtown", "Campbellton Road", "Morningside/Lenox Park", "Norwood Manor", "Florida Heights", null, "Sweet Auburn", "Center Hill", "Old Fourth Ward", "Poncey-Highland", "Ridgedale Park", "English Avenue", "Hills Park", "Marietta Street Artery", "Pittsburgh", "Ben Hill Terrace", "Wilson Mill Meadows", "Harland Terrace", "Home Park", "Pittsburgh", "Edgewood", "Vine City", "Castleberry Hill", "Grant Park", null, "West End", "Loring Heights", "Capitol View", "Edgewood", "Downtown", "Grove Park", "Atlantic Station", "Lake Claire", "Downtown", "Hammond Park", "Virginia Highland", "Adamsville", "Midtown", "Inman Park", "Peachtree Heights West", "Summerhill", "Grove Park", "Harris Chiles", "West End", "Harland Terrace", "Downtown", "Grove Park", "Downtown", "Downtown", "Garden Hills", "Downtown", null, "Castleberry Hill", "Polar Rock", "Underwood Hills", "Cascade Heights", "Downtown", "Oakland City", "Sylvan Hills", "West End", "Midtown", "South Tuxedo Park", "Sweet Auburn", "Grove Park", "Adams Park", "Peachtree Hills", "North Buckhead", "Downtown", "Marietta Street Artery", "Adamsville", "Collier Heights", "Grove Park", "Blandtown", "Virginia Highland", "Reynoldstown", "Greenbriar Village", "Scotts Crossing", "Garden Hills", "Westview", "Castleberry Hill", "Loring Heights", "Downtown", "Venetian Hills", "Harland Terrace", "Monroe Heights", "Pittsburgh", "Venetian Hills", "Hunter Hills", "Adair Park", "Lakewood", "West End", "Marietta Street Artery", "Hunter Hills", "Kirkwood", "Midtown", "Kirkwood", "Sylvan Hills", "Blair Villa/Poole Creek", "Atlanta University Center", "Grant Park", "Downtown", "Grant Park", "Adams Park", "Carver Hills", "Edgewood", null, "Atlanta University Center", "Downtown", "Midtown", "Buckhead Forest", "Mechanicsville", "Chosewood Park", "East Atlanta", "Mechanicsville", "Grove Park", "Browns Mill Park", "Downtown", "Poncey-Highland", "Thomasville Heights", "Berkeley Park", "Cross Creek", "Marietta Street Artery", "Pittsburgh", "West End", "Adams Park", "Bankhead", "Southwest", "Chosewood Park", "Buckhead Village", "Oakland City", "Princeton Lakes", "Sylvan Hills", "Grant Park", "Garden Hills", "Greenbriar", "Berkeley Park", " ...

# %% [markdown]
# _Conclusions_
#
# ---
# The neighborhoods with the largest crime rates are Midtown, Downtown, Old Fourth Ward, and Westend.

# %% [markdown]
# ## Location
# ---

# %%
BBox = ((atlanta.Longitude.min(), atlanta.Longitude.max(),atlanta.Latitude.min(), atlanta.Latitude.max()))
BBox
# Out:
# (-84.54850999999998, -84.29074, 33.64883, 33.87957)

# %%
img = plt.imread('map.png')
fig, ax = plt.subplots(figsize = (15,12))
ax.scatter(atlanta.Longitude, atlanta.Latitude, zorder=1, alpha= .1,c='b', s=10)
ax.set_title('Plotting Crime Map')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(img, zorder=0, extent = BBox, aspect= 'equal')

# %% [markdown]
# _Conclusions_
#
# ---
# There is more crime the closer to the city you are. Also there seems to be less crime around the airport.

# %% [markdown]
# # __MACHINE LEARNING__
# ---
# ---

# %%
atlanta.head()
# Out:
#        Report Date  Occur Date Occur Time Possible Date  Possible Time   Beat  \
# 143571  2013-01-04  2013-01-04       1720    2013-01-04         1727.0  609.0
# 29715   2009-10-03  2009-10-03        210    2009-10-03          210.0  108.0
# 234530  2015-12-02  2015-12-02        605    2015-12-02          606.0  403.0
# 218953  2015-06-07  2015-06-07       1300    2015-06-07         2030.0  502.0
# 174347  2013-12-16  2013-12-14       1000    2013-12-15         1105.0  306.0
#
#        Shift Occurence           UCR Literal  UCR # IBR Code     Neighborhood  \
# 143571   Evening Watch   LARCENY-NON VEHICLE    630     2303         Edgewood
# 29715    Morning Watch    ROBBERY-PEDESTRIAN    311     1204  Florida Heights
# 234530   Morning Watch  LARCENY-FROM VEHICLE    650     2304     Oakland City
# 218953   Evening Watch  LARCENY-FROM VEHICLE    640     2305          Midtown
# 174347       Day Watch            AUTO THEFT    710     2404     Sylvan Hills
#
#        NPU  Latitude  Longitude        Crime
# 143571   O  33.75605  -84.34813      Larceny
# 29715    I  33.75260  -84.46294      Robbery
# 234530   S  33.72464  -84.42836      Larceny
# 218953   E  33.78699  -84.38371      Larceny
# 174347   X  33.71495  -84.41863  Motor_theft

# %% [markdown]
# ## Label Encoding

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
    
atl = atlanta.apply(lambda col: le.fit_transform(col.astype(str)), axis=0, result_type='expand')
atl.head()
# Out:
#         Report Date  Occur Date  Occur Time  Possible Date  Possible Time  \
# 143571         2184        2176         285            902            340
# 29715          1002        1035         383            190            485
# 234530          587         581         556           1509            745
# 218953          473         463         142           1406            466
# 174347          118         122          57           1094             51
#
#         Beat  Shift Occurence  UCR Literal  UCR #  IBR Code  Neighborhood  \
# 143571    74                1            6     32        35            71
# 29715      8                2            8      1        10            79
# 234530    42                2            5     34        36           129
# 218953    55                1            5     33        37           118
# 174347    32                0            1     39        46           171
#
#         NPU  Latitude  Longitude  Crime
# 143571   14      1230        146      3
# 29715     8      1122       2070      5
# 234530   18       536       1748      3
# 218953    4      1929        827      3
# 174347   22       419       1613      4

# %% [markdown]
# ## Create train and test data

# %%
from sklearn.model_selection import train_test_split

# Going to base the outcome based on these features
feature_cols = ['Occur Time', 'Neighborhood', 'Beat']

# X is a matrix, access the features we want in feature_cols
X = atl[feature_cols]

# y is a vector, hence we use dot to access 'label'
y = atl['Crime']

# split X and y into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

y_test.value_counts()
# Out:
# 3    452
# 1    175
# 4    129
# 0     55
# 5     43
# 2      4
# Name: Crime, dtype: int64

# %% [markdown]
# ## Histogram

# %%
# create and plot a histogram based on y_test
plt.hist(y_test, bins=20)
plt.show()

# count how many of each crime exists
y_test_pd_series = pd.Series(y_test)
y_test_pd_series.value_counts()
# Out:
# 3    452
# 1    175
# 4    129
# 0     55
# 5     43
# 2      4
# Name: Crime, dtype: int64

# %% [markdown]
# ## Logistic Regression and Confusion Matrix

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()

# fit model
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

print(y_pred)

print('\n\n\n')

from sklearn import metrics

confusion = metrics.confusion_matrix(y_test, y_pred)
print(confusion)

TP = confusion[1, 1]
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]
# Out:
# [3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3]
#
#
#
#
# [[  0   0   0  55   0   0]
#  [  0   0   0 175   0   0]
#  [  0   0   0   4   0   0]
#  [  0   0   0 452   0   0]
#  [  0   0   0 129   0   0]
#  [  0   0   0  43   0   0]]
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning:
#
# Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.

# %%
fig = plt.figure(figsize = (20, 25))
j = 0
for i in atl.columns:
    plt.subplot(7, 4, j+1 )
    j += 1 
    sns.distplot(atl[i][atl['Crime']==0], color='g', label = 'a', kde_kws={'bw': 0.1})
    sns.distplot(atl[i][atl['Crime']==1], color='r', label = 'b',kde_kws={'bw': 0.1})
    sns.distplot(atl[i][atl['Crime']==2], color='y', label = 'c',kde_kws={'bw': 0.1})
    sns.distplot(atl[i][atl['Crime']==3], color='b', label = 'Larceny',kde_kws={'bw': 0.1})
    sns.distplot(atl[i][atl['Crime']==4], color='c', label = 'e',kde_kws={'bw': 0.1})
    sns.distplot(atl[i][atl['Crime']==5], color='k', label = 'f',kde_kws={'bw': 0.1})
    plt.legend(loc='best')
fig.suptitle('Crimes by Feature')
fig.tight_layout()
fig.subplots_adjust(top=0.95 )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-79-c7662f230dca> in <module>
#       6     sns.distplot(atl[i][atl['Crime']==0], color='g', label = 'a', kde_kws=None)
#       7     sns.distplot(atl[i][atl['Crime']==1], color='r', label = 'b',kde_kws=None)
# ----> 8     sns.distplot(atl[i][atl['Crime']==2], color='y', label = 'c',kde_kws=None)
#       9     sns.distplot(atl[i][atl['Crime']==3], color='b', label = 'Larceny',kde_kws=None)
#      10     sns.distplot(atl[i][atl['Crime']==4], color='c', label = 'e',kde_kws=None)
#
# ~/Library/Python/3.7/lib/python/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
#     232         kde_color = kde_kws.pop("color", color)
# --> 233         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     234         if kde_color != color:
#     235             kde_kws["color"] = kde_color
#
# ~/Library/Python/3.7/lib/python/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     703         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     704                                  gridsize, cut, clip, legend, ax,
# --> 705                                  cumulative=cumulative, **kwargs)
#     706
#     707     return ax
#
# ~/Library/Python/3.7/lib/python/site-packages/seaborn/distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     293         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     294                                            gridsize, cut, clip,
# --> 295                                            cumulative=cumulative)
#     296     else:
#     297         # Fall back to scipy if missing statsmodels
#
# ~/Library/Python/3.7/lib/python/site-packages/seaborn/distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     365     fft = kernel == "gau"
#     366     kde = smnp.KDEUnivariate(data)
# --> 367     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     368     if cumulative:
#     369         grid, y = kde.support, kde.cdf
#
# /usr/local/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     138             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     139                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 140                     clip=clip, cut=cut)
#     141         else:
#     142             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# /usr/local/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     451         bw = float(bw)
#     452     except:
# --> 453         bw = bandwidths.select_bandwidth(X, bw, kern) # will cross-val fit this pattern?
#     454     bw *= adjust
#     455
#
# /usr/local/lib/python3.7/site-packages/statsmodels/nonparametric/bandwidths.py in select_bandwidth(x, bw, kernel)
#     172         # eventually this can fall back on another selection criterion.
#     173         err = "Selected KDE bandwidth is 0. Cannot estimate density."
# --> 174         raise RuntimeError(err)
#     175     else:
#     176         return bandwidth
#
# RuntimeError: Selected KDE bandwidth is 0. Cannot estimate density.
